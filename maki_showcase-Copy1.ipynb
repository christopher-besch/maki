# %% [markdown]
# # Maki or How to Teach Manim Time Travel

# %% [markdown]
# ### Setup

# %%
import maki

# %%
maki.init(maki.RendererImplementation.opengl)

# %%
render_driver = maki.RenderDriver("Maki Showcase Window", 1280, 720)
# Out:
# [15:33:04] Maki:	Initializing GLFW.

# %% [markdown]
# ## Raw Cuboids

# %%
cuboid = render_driver.add_cuboid_atom()

# %%
render_driver.show_cuboid_atom(cuboid, 1, True)

# %% [markdown]
# ### Colouring

# %%
render_driver.color_cuboid_atom(cuboid, 2, maki.vec4(1.0, 1.0, 0.0, 1.0))

# %%
render_driver.color_cuboid_atom(cuboid, 3, maki.vec4(1.0, 0.0, 1.0, 1.0))
render_driver.color_cuboid_atom(cuboid, 4, maki.vec4(0.5, 0.5, 0.5, 1.0))
render_driver.color_cuboid_atom(cuboid, 5, maki.vec4(0.8, 0.0, 0.4, 1.0))

# %% [markdown]
# ### Translation

# %%
render_driver.translate_cuboid_atom(cuboid, 6, maki.vec3(0.0, 1.0, 0.0))

# %%
target_delta = maki.vec3(10.0, 10.0, 5.0)
first_frame = 60       # alpha = 0.0
after_last_frame = 200 # alpha = 1.0

alpha_delta = 1 / (after_last_frame - first_frame)
for frame in range(first_frame, after_last_frame):
    cur_delta = target_delta * alpha_delta
    render_driver.translate_cuboid_atom(cuboid, frame, cur_delta)
# Out:
# [15:33:04] Maki:	Creating GLFW window 'Maki Showcase Window' (1280, 720).

# %% [markdown]
# ## Time Travel

# %%
target_delta = maki.vec3(0.0, -5.0, 0.0)
first_frame = 5       # alpha = 0.0
after_last_frame = 50 # alpha = 1.0
alpha_delta = 1 / (after_last_frame - first_frame)
for frame in range(first_frame, after_last_frame):
    cur_delta = target_delta * alpha_delta
    render_driver.translate_cuboid_atom(cuboid, frame, cur_delta)

# %% [markdown]
# ## Abstraction

# %%
from abc import abstractmethod

# this is not clean code, it's just a showcase
class Mobject:
    def __init__(self, render_driver: maki.RenderDriver):
        self.render_driver = render_driver
    
    @abstractmethod
    def show(self, frame: int):
        pass
    @abstractmethod
    def hide(self, frame: int):
        pass
    
    @abstractmethod
    def translate(self, delta: maki.vec3, first_frame: int, after_last_frame: int):
        pass


class Cube(Mobject):
    def __init__(self, render_driver: maki.RenderDriver, first_frame: int):
        super().__init__(render_driver)
        self.cuboid_atom = render_driver.add_cuboid_atom()
        self.show(first_frame)
        
    def show(self, frame: int):
        self.render_driver.show_cuboid_atom(self.cuboid_atom, frame, True)
    def hide(self, frame: int):
        self.render_driver.show_cuboid_atom(self.cuboid_atom, frame, False)
        
    def translate(self, delta: maki.vec3, first_frame: int, after_last_frame: int):
        alpha_delta = 1 / (after_last_frame - first_frame)
        for frame in range(first_frame, after_last_frame):
            cur_delta = delta * alpha_delta
            self.render_driver.translate_cuboid_atom(self.cuboid_atom, frame, cur_delta)

# %%
c = Cube(render_driver, 5)

# %%
c.translate(maki.vec3(0.0, 0.0, 20.0), 10, 300)

# %% [markdown]
# ### Text

# %%
import random


# again, this is very unclean code
def get_random_color():
    return maki.vec4(random.uniform(0.0, 1.0), random.uniform(0.0, 1.0), random.uniform(0.0, 1.0), 1.0)


class TextCubes(Mobject):
    cubes = []
    
    def __init__(self, render_driver: maki.RenderDriver, first_frame: int, after_last_frame: int, text: str):
        super().__init__(render_driver)
        alpha_delta = 1 / (after_last_frame - first_frame)
        font = self.load_font()
        rendered_text = self.render_text(text, *font)
        y = 0.0
        spacing = 3.0
        for line in rendered_text:
            x = 0.0
            for char in line:
                if char == "#":
                    self.cubes.append(self.render_driver.add_cuboid_atom())
                    for frame in range(first_frame, after_last_frame):
                        self.render_driver.translate_cuboid_atom(self.cubes[-1], frame, maki.vec3(x, -y, 0) * alpha_delta)
                    self.render_driver.color_cuboid_atom(self.cubes[-1], random.randint(int(first_frame + (after_last_frame - first_frame) / 2), after_last_frame - 1), get_random_color())
                x += spacing
            y += spacing
        self.show(first_frame)
        
    def show(self, frame: int):
        for cube in self.cubes:
            self.render_driver.show_cuboid_atom(cube, frame, True)
    def hide(self, frame: int):
        for cube in self.cubes:
            self.render_driver.show_cuboid_atom(cube, frame, False)
        
    def translate(self, delta: maki.vec3, first_frame: int, after_last_frame: int):
        alpha_delta = 1 / (after_last_frame - first_frame)
        for frame in range(first_frame, after_last_frame):
            cur_delta = delta * alpha_delta
            for cube in self.cubes:
                self.render_driver.translate_cuboid_atom(cube, frame, cur_delta)
    
    def load_font(self):
        chars = {}
        with open(f"block.txt", "r", encoding="utf-8") as file:
            height = int(file.readline().split(":")[-1])
            spacing = int(file.readline().split(":")[-1])
            while line := file.readline():
                if line[0] == "-":
                    code = int(line[1:])
                    char = []
                    for _ in range(0, height):
                        char.append(list(file.readline().strip("\n"))[::2])
                    chars[code] = char
        return (chars, height, spacing)


    def render_text(self, text, font_chars, height, spacing):
        # rows to be printed
        output_lines = []
        for input_line in text.split("\n"):
            # filling lines with pixels of one char after another
            new_output_lines = [[] for _ in range(height)]
            for input_char in input_line:
                # convert input char into array of pixels
                output_char_rows = font_chars[ord(input_char)]
                for new_output_line, output_char_row in zip(new_output_lines, output_char_rows):
                    new_output_line += output_char_row
            output_lines += new_output_lines

        output_strings = ["".join(line).replace("_", "#").replace("|", "#") for line in output_lines]
        return output_strings

# %%
t = TextCubes(render_driver, 1, 200, "Hello World")
# Out:
# [15:33:04] Maki:	Creating OpenGL Renderer.
# [15:33:04] Maki:	Initializing GLEW.
# [15:33:04] Maki:	Shaders linked.
# [15:33:04] Maki:	Shaders linked.

# %%
from PIL import Image
import numpy as np
import itertools
import os

# again, garbage code
class ImageRects(Mobject):
    rects = []
    WIDTH = 96
    HEIGHT = 72
    SPACING = 3
    
    def __init__(self, render_driver: maki.RenderDriver, first_frame: int, after_last_frame: int, path: str, z: float):
        super().__init__(render_driver)
        
        image = Image.open(path)
        image = image.resize((self.WIDTH, self.HEIGHT), Image.ANTIALIAS)
        image_data = np.asarray(image)
        
        for (x, y), frame in zip(itertools.product(range(self.WIDTH), range(self.HEIGHT)), np.linspace(first_frame, after_last_frame, num=self.WIDTH*self.HEIGHT, endpoint=False)):
            # create rect
            self.rects.append(self.render_driver.add_quadrilateral_atom())
            print("created")
            # position rect
            self.render_driver.translate_quadrilateral_atom(self.rects[-1], 1, maki.vec3(x * self.SPACING, -y * self.SPACING, z))
            print("translated")
            # set color
            self.render_driver.color_quadrilateral_atom(self.rects[-1], 1, maki.vec4(float(image_data[y][x][0]/256), float(image_data[y][x][1]/256), float(image_data[y][x][2]/256), 1.0))
            print("coloured")
            # show rect
            self.render_driver.show_quadrilateral_atom(self.rects[-1], int(frame), True)
            print("showed")
            
        print(f"created {path}")
        
    def show(self, frame: int):
        for cube in self.cubes:
            self.render_driver.show_quadrilateral_atom(cube, frame, True)
    def show(self, frame: int):
        for rect in self.rects:
            self.render_driver.show_quadrilateral_atom(rect, frame, True)
        
    def translate(self, delta: maki.vec3, first_frame: int, after_last_frame: int):
        alpha_delta = 1 / (after_last_frame - first_frame)
        for frame in range(first_frame, after_last_frame):
            cur_delta = delta * alpha_delta
            for rect in self.rects:
                self.render_driver.translate_quadrilateral_atom(rect, frame, cur_delta)

class VideoRects(Mobject):
    images = []
    SPACING = 3
    
    def __init__(self, render_driver: maki.RenderDriver, first_frame: int, after_last_frame: int, path: str, frames):
        super().__init__(render_driver)
        
        frame_space = np.linspace(first_frame, after_last_frame, num=frames+1, endpoint=False)
        
        for frame in range(1, frames+1):
            self.images.append(ImageRects(self.render_driver, frame_space[frame-1], frame_space[frame], os.path.join(path, f"{frame:02d}.png"), frame * self.SPACING))
    
    def show(self, frame: int):
        for image in self.images:
            image.show(frame)
    def hide(self, frame: int):
        for image in self.images:
            image.hide(frame)
    def translate(self, delta: maki.vec3, first_frame: int, after_last_frame: int):
        for image in self.images:
            image.translate(delta, first_frame, after_last_frame)
    
t = VideoRects(render_driver, 500, 1000, "examples/rick", 31)
# Out:
# created examples/rick/01.png
# created examples/rick/02.png
# created examples/rick/03.png
# created examples/rick/04.png
# created examples/rick/05.png
# created examples/rick/06.png
# created examples/rick/07.png
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:43] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:44] Maki:	Chrono Sync initiated.
# [15:34:45] Maki:	Chrono Sync initiated.
# [15:34:45] Maki:	Chrono Sync initiated.
# [15:34:45] Maki:	Chrono Sync initiated.
# [15:34:46] Maki:	Chrono Sync initiated.
# [15:34:46] Maki:	Chrono Sync initiated.
# [15:34:46] Maki:	Chrono Sync initiated.
# [15:34:46] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:47] Maki:	Chrono Sync initiated.
# [15:34:48] Maki:	Chrono Sync initiated.
# [15:34:48] Maki:	Chrono Sync initiated.
# [15:34:48] Maki:	Chrono Sync initiated.
# [15:34:49] Maki:	Chrono Sync initiated.
# [15:34:49] Maki:	Chrono Sync initiated.
# [15:34:49] Maki:	Chrono Sync initiated.
# [15:34:49] Maki:	Chrono Sync initiated.
# [15:34:49] Maki:	Chrono Sync initiated.
# [15:34:50] Maki:	Chrono Sync initiated.
# [15:34:50] Maki:	Chrono Sync initiated.
# [15:34:50] Maki:	Chrono Sync initiated.
# [15:34:50] Maki:	Chrono Sync initiated.
# [15:34:50] Maki:	Chrono Sync initiated.
# [15:34:50] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:51] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:52] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:53] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:54] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:55] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:56] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:57] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:58] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:34:59] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:00] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:01] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:02] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:03] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:04] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:05] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:06] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:07] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:08] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:09] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:10] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:11] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:12] Maki:	Chrono Sync initiated.
# [15:35:13] Maki:	Chrono Sync initiated.
# [15:35:13] Maki:	Chrono Sync initiated.
# [15:35:13] Maki:	Chrono Sync initiated.
# [15:35:14] Maki:	Chrono Sync initiated.
# [15:35:14] Maki:	Chrono Sync initiated.
# [15:35:14] Maki:	Chrono Sync initiated.
# [15:35:14] Maki:	Chrono Sync initiated.
# [15:35:14] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:15] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:16] Maki:	Chrono Sync initiated.
# [15:35:17] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:18] Maki:	Chrono Sync initiated.
# [15:35:19] Maki:	Chrono Sync initiated.
# [15:35:20] Maki:	Chrono Sync initiated.
# [15:35:20] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:21] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:22] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:23] Maki:	Chrono Sync initiated.
# [15:35:24] Maki:	Chrono Sync initiated.
# [15:35:24] Maki:	Chrono Sync initiated.
# [15:35:24] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:25] Maki:	Chrono Sync initiated.
# [15:35:26] Maki:	Chrono Sync initiated.
# [15:35:26] Maki:	Chrono Sync initiated.
# [15:35:26] Maki:	Chrono Sync initiated.
# [15:35:26] Maki:	Chrono Sync initiated.
# [15:35:26] Maki:	Chrono Sync initiated.
# [15:35:26] Maki:	Chrono Sync initiated.
# [15:35:27] Maki:	Chrono Sync initiated.
# [15:35:27] Maki:	Chrono Sync initiated.
# [15:35:27] Maki:	Chrono Sync initiated.
# [15:35:27] Maki:	Chrono Sync initiated.
# [15:35:27] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:28] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:29] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:30] Maki:	Chrono Sync initiated.
# [15:35:31] Maki:	Chrono Sync initiated.
# [15:35:31] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:32] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:33] Maki:	Chrono Sync initiated.
# [15:35:34] Maki:	Chrono Sync initiated.
# [15:35:34] Maki:	Chrono Sync initiated.
# [15:35:34] Maki:	Chrono Sync initiated.
# [15:35:34] Maki:	Chrono Sync initiated.
# [15:35:34] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# [15:35:35] Maki:	Chrono Sync initiated.
# created examples/rick/08.png
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:36] Maki:	Chrono Sync initiated.
# [15:35:37] Maki:	Chrono Sync initiated.
# [15:35:37] Maki:	Chrono Sync initiated.
# [15:35:38] Maki:	Chrono Sync initiated.
# [15:35:38] Maki:	Chrono Sync initiated.
# [15:35:38] Maki:	Chrono Sync initiated.
# [15:35:38] Maki:	Chrono Sync initiated.
# [15:35:38] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:39] Maki:	Chrono Sync initiated.
# [15:35:40] Maki:	Chrono Sync initiated.
# [15:35:40] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:41] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:42] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:43] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:44] Maki:	Chrono Sync initiated.
# [15:35:45] Maki:	Chrono Sync initiated.
# [15:35:45] Maki:	Chrono Sync initiated.
# [15:35:45] Maki:	Chrono Sync initiated.
# [15:35:45] Maki:	Chrono Sync initiated.
# [15:35:45] Maki:	Chrono Sync initiated.
# [15:35:45] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# [15:35:46] Maki:	Chrono Sync initiated.
# created examples/rick/09.png
# created examples/rick/10.png
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:31] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:32] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:33] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:34] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:35] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:36] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:37] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:38] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:39] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:40] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# [15:37:41] Maki:	Chrono Sync initiated.
# ...
# [17:01:26] Maki:	Chrono Sync initiated.
# [17:01:26] Maki:	Chrono Sync initiated.
# [17:01:26] Maki:	Chrono Sync initiated.
# [17:01:26] Maki:	Chrono Sync initiated.
# [17:01:26] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:27] Maki:	Chrono Sync initiated.
# [17:01:28] Maki:	Chrono Sync initiated.
# [17:01:28] Maki:	Chrono Sync initiated.
# [17:01:28] Maki:	Chrono Sync initiated.
# [17:01:28] Maki:	Chrono Sync initiated.
# [17:01:29] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:30] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:31] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:32] Maki:	Chrono Sync initiated.
# [17:01:33] Maki:	Chrono Sync initiated.
# [17:01:33] Maki:	Chrono Sync initiated.
# [17:01:33] Maki:	Chrono Sync initiated.
# [17:01:33] Maki:	Chrono Sync initiated.
# [17:01:33] Maki:	Chrono Sync initiated.
# [17:01:34] Maki:	Chrono Sync initiated.
# [17:01:34] Maki:	Chrono Sync initiated.
# [17:01:34] Maki:	Chrono Sync initiated.
# [17:01:34] Maki:	Chrono Sync initiated.
# [17:01:34] Maki:	Chrono Sync initiated.
# [17:01:35] Maki:	Chrono Sync initiated.
# [17:01:35] Maki:	Chrono Sync initiated.
# [17:01:35] Maki:	Chrono Sync initiated.
# [17:01:35] Maki:	Chrono Sync initiated.
# [17:01:35] Maki:	Chrono Sync initiated.
# [17:01:35] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:36] Maki:	Chrono Sync initiated.
# [17:01:37] Maki:	Chrono Sync initiated.
# [17:01:37] Maki:	Chrono Sync initiated.
# [17:01:38] Maki:	Chrono Sync initiated.
# [17:01:38] Maki:	Chrono Sync initiated.
# [17:01:38] Maki:	Chrono Sync initiated.
# [17:01:38] Maki:	Chrono Sync initiated.
# [17:01:39] Maki:	Chrono Sync initiated.
# [17:01:39] Maki:	Chrono Sync initiated.
# [17:01:39] Maki:	Chrono Sync initiated.
# [17:01:39] Maki:	Chrono Sync initiated.
# [17:01:39] Maki:	Chrono Sync initiated.
# [17:01:39] Maki:	Chrono Sync initiated.
# [17:01:40] Maki:	Chrono Sync initiated.
# [17:01:40] Maki:	Chrono Sync initiated.
# [17:01:42] Maki:	Chrono Sync initiated.
# [17:01:42] Maki:	Chrono Sync initiated.
# [17:01:42] Maki:	Chrono Sync initiated.
# [17:01:42] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:43] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:44] Maki:	Chrono Sync initiated.
# [17:01:45] Maki:	Chrono Sync initiated.
# [17:01:45] Maki:	Chrono Sync initiated.
# [17:01:45] Maki:	Chrono Sync initiated.
# [17:01:45] Maki:	Chrono Sync initiated.
# [17:01:45] Maki:	Chrono Sync initiated.
# [17:01:45] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:46] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:47] Maki:	Chrono Sync initiated.
# [17:01:48] Maki:	Chrono Sync initiated.
# [17:01:48] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:49] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:50] Maki:	Chrono Sync initiated.
# [17:01:51] Maki:	Chrono Sync initiated.
# [17:01:51] Maki:	Chrono Sync initiated.
# [17:01:52] Maki:	Chrono Sync initiated.
# [17:01:52] Maki:	Chrono Sync initiated.
# [17:01:52] Maki:	Chrono Sync initiated.
# [17:01:52] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:53] Maki:	Chrono Sync initiated.
# [17:01:54] Maki:	Chrono Sync initiated.
# [17:01:54] Maki:	Chrono Sync initiated.
# [17:01:54] Maki:	Chrono Sync initiated.
# [17:01:54] Maki:	Chrono Sync initiated.
# [17:01:54] Maki:	Chrono Sync initiated.
# [17:01:54] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:55] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:56] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:57] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:58] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:01:59] Maki:	Chrono Sync initiated.
# [17:02:00] Maki:	Chrono Sync initiated.
# [17:02:00] Maki:	Chrono Sync initiated.
# [17:02:00] Maki:	Chrono Sync initiated.
# [17:02:00] Maki:	Chrono Sync initiated.
# [17:02:00] Maki:	Chrono Sync initiated.
# [17:02:00] Maki:	Chrono Sync initiated.
# [17:02:01] Maki:	Chrono Sync initiated.
# [17:02:01] Maki:	Chrono Sync initiated.
# [17:02:01] Maki:	Chrono Sync initiated.
# [17:02:01] Maki:	Chrono Sync initiated.
# [17:02:02] Maki:	Chrono Sync initiated.
# [17:02:02] Maki:	Chrono Sync initiated.
# [17:02:02] Maki:	Chrono Sync initiated.
# [17:02:02] Maki:	Chrono Sync initiated.
# [17:02:03] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:04] Maki:	Chrono Sync initiated.
# [17:02:05] Maki:	Chrono Sync initiated.
# [17:02:05] Maki:	Chrono Sync initiated.
# [17:02:06] Maki:	Chrono Sync initiated.
# [17:02:06] Maki:	Chrono Sync initiated.
# [17:02:06] Maki:	Chrono Sync initiated.
# [17:02:06] Maki:	Chrono Sync initiated.
# [17:02:07] Maki:	Chrono Sync initiated.
# [17:02:08] Maki:	Chrono Sync initiated.
# [17:02:08] Maki:	Chrono Sync initiated.
# [17:02:08] Maki:	Chrono Sync initiated.
# [17:02:08] Maki:	Chrono Sync initiated.
# [17:02:08] Maki:	Chrono Sync initiated.
# [17:02:09] Maki:	Chrono Sync initiated.
# [17:02:09] Maki:	Chrono Sync initiated.
# [17:02:09] Maki:	Chrono Sync initiated.
# [17:02:09] Maki:	Chrono Sync initiated.
# [17:02:09] Maki:	Chrono Sync initiated.
# [17:02:10] Maki:	Chrono Sync initiated.
# [17:02:11] Maki:	Chrono Sync initiated.
# [17:02:12] Maki:	Chrono Sync initiated.
# [17:02:12] Maki:	Chrono Sync initiated.
# [17:02:12] Maki:	Chrono Sync initiated.
# [17:02:12] Maki:	Chrono Sync initiated.
# [17:02:13] Maki:	Chrono Sync initiated.
# [17:02:13] Maki:	Chrono Sync initiated.
# [17:02:13] Maki:	Chrono Sync initiated.
# [17:02:13] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:14] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:15] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:16] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:17] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:18] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:21] Maki:	Chrono Sync initiated.
# [17:02:22] Maki:	Chrono Sync initiated.
# [17:02:22] Maki:	Chrono Sync initiated.
# [17:02:22] Maki:	Chrono Sync initiated.
# [17:02:22] Maki:	Chrono Sync initiated.
# [17:02:23] Maki:	Chrono Sync initiated.
# [17:02:23] Maki:	Chrono Sync initiated.
# [17:02:23] Maki:	Chrono Sync initiated.
# [17:02:23] Maki:	Chrono Sync initiated.
# [17:02:25] Maki:	Chrono Sync initiated.
# [17:02:26] Maki:	Chrono Sync initiated.
# [17:02:26] Maki:	Chrono Sync initiated.
# [17:02:26] Maki:	Chrono Sync initiated.
# [17:02:26] Maki:	Chrono Sync initiated.
# [17:02:27] Maki:	Chrono Sync initiated.
# [17:02:27] Maki:	Chrono Sync initiated.
# [17:02:27] Maki:	Chrono Sync initiated.
# [17:02:27] Maki:	Chrono Sync initiated.
# [17:02:28] Maki:	Chrono Sync initiated.
# [17:02:28] Maki:	Chrono Sync initiated.
# [17:02:28] Maki:	Chrono Sync initiated.
# [17:02:28] Maki:	Chrono Sync initiated.
# [17:02:28] Maki:	Chrono Sync initiated.
# [17:02:28] Maki:	Chrono Sync initiated.
# [17:02:29] Maki:	Chrono Sync initiated.
# [17:02:29] Maki:	Chrono Sync initiated.
# [17:02:29] Maki:	Chrono Sync initiated.
# [17:02:29] Maki:	Chrono Sync initiated.
# [17:02:29] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:30] Maki:	Chrono Sync initiated.
# [17:02:31] Maki:	Chrono Sync initiated.
# [17:02:31] Maki:	Chrono Sync initiated.
# [17:02:31] Maki:	Chrono Sync initiated.
# [17:02:31] Maki:	Chrono Sync initiated.
# [17:02:32] Maki:	Chrono Sync initiated.
# [17:02:32] Maki:	Chrono Sync initiated.
# [17:02:32] Maki:	Chrono Sync initiated.
# [17:02:32] Maki:	Chrono Sync initiated.
# [17:02:32] Maki:	Chrono Sync initiated.
# [17:02:33] Maki:	Chrono Sync initiated.
# [17:02:33] Maki:	Chrono Sync initiated.
# [17:02:34] Maki:	Chrono Sync initiated.
# [17:02:34] Maki:	Chrono Sync initiated.
# [17:02:34] Maki:	Chrono Sync initiated.
# [17:02:34] Maki:	Chrono Sync initiated.
# [17:02:35] Maki:	Chrono Sync initiated.
# [17:02:36] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:37] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:38] Maki:	Chrono Sync initiated.
# [17:02:39] Maki:	Chrono Sync initiated.
# [17:02:39] Maki:	Chrono Sync initiated.
# [17:02:39] Maki:	Chrono Sync initiated.
# [17:02:39] Maki:	Chrono Sync initiated.
# [17:02:39] Maki:	Chrono Sync initiated.
# [17:02:39] Maki:	Chrono Sync initiated.
# [17:02:40] Maki:	Chrono Sync initiated.
# [17:02:41] Maki:	Chrono Sync initiated.
# [17:02:41] Maki:	Chrono Sync initiated.
# [17:02:42] Maki:	Chrono Sync initiated.
# [17:02:42] Maki:	Chrono Sync initiated.
# [17:02:42] Maki:	Chrono Sync initiated.
# [17:02:42] Maki:	Chrono Sync initiated.
# [17:02:42] Maki:	Chrono Sync initiated.
# [17:02:43] Maki:	Chrono Sync initiated.
# [17:02:43] Maki:	Chrono Sync initiated.
# [17:02:43] Maki:	Chrono Sync initiated.
# [17:02:43] Maki:	Chrono Sync initiated.
# [17:02:43] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:44] Maki:	Chrono Sync initiated.
# [17:02:45] Maki:	Chrono Sync initiated.
# [17:02:45] Maki:	Chrono Sync initiated.
# [17:02:45] Maki:	Chrono Sync initiated.
# created examples/rick/31.png
